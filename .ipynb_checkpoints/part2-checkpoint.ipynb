# %% [markdown]
# ### PART 2 OVERVIEW

# %% [markdown]
# We have been provided with data on the under-five mortality rate and neonatal mortality rate for the African region, which has been downloaded from the UN Inter-agency Group for Child Mortality Estimation.

# %% [markdown]
# ##### Objectives
#
# 1. Filter data for the eight countries belonging to the East African Community.
#
# 2. Visualize the latest estimate of each indicator at the country level using shapefiles.
#
# 3. Show the average trends in the mortality rates over time (plot the average trend line and add the points in the graphic for the country level estimates for each indicator).
#
# 4. Based on the visualizations, identify the countries with the highest under-five mortality rates in East Africa and the highest neonatal mortality.

# %% [markdown]
# ##### Data Cleaning

# %%
#load the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import geopandas as gpd
import seaborn as sns 
import os

# %%
#load data

INR = pd.read_csv('dataset_datascience.csv', encoding='latin1', low_memory=False)

INR
# Out:
#        REF_AREA Geographic area Regional group                  Indicator  \
# 0           AFG     Afghanistan            NaN    Neonatal mortality rate
# 1           AFG     Afghanistan            NaN    Neonatal mortality rate
# 2           AFG     Afghanistan            NaN    Neonatal mortality rate
# 3           AFG     Afghanistan            NaN    Neonatal mortality rate
# 4           AFG     Afghanistan            NaN    Neonatal mortality rate
# ...         ...             ...            ...                        ...
# 129559      ZWE        Zimbabwe            NaN  Under-five mortality rate
# 129560      ZWE        Zimbabwe            NaN  Under-five mortality rate
# 129561      ZWE        Zimbabwe            NaN  Under-five mortality rate
# 129562      ZWE        Zimbabwe            NaN  Under-five mortality rate
# 129563      ZWE        Zimbabwe            NaN  Under-five mortality rate
#
#           Sex Wealth Quintile                              Series Name  \
# 0       Total           Total  Afghanistan Health Survey 2018 (Direct)
# 1       Total           Total  Afghanistan Health Survey 2018 (Direct)
# 2       Total           Total  Afghanistan Health Survey 2018 (Direct)
# 3       Total           Total  Afghanistan Health Survey 2018 (Direct)
# 4       Total           Total  Afghanistan Health Survey 2018 (Direct)
# ...       ...             ...                                      ...
# 129559  Total           Total                         UN IGME estimate
# 129560  Total           Total                         UN IGME estimate
# 129561  Total           Total                         UN IGME estimate
# 129562  Total           Total                         UN IGME estimate
# 129563  Total           Total                         UN IGME estimate
#
#        Series Year  Reference Date  Observation Value  ...  Country notes  \
# 0             2018          1995.5          47.869030  ...            NaN
# 1             2018          2000.5          35.349317  ...            NaN
# 2             2018          2005.5          27.699219  ...            NaN
# 3             2018          2010.5          21.056003  ...            NaN
# 4             2018          2015.5          20.167379  ...            NaN
# ...            ...             ...                ...  ...            ...
# 129559        2023          2019.5          51.062569  ...            NaN
# 129560        2023          2020.5          50.083316  ...            NaN
# 129561        2023          2021.5          47.620611  ...            NaN
# 129562        2023          2022.5          45.985854  ...            NaN
# 129563        2023          2023.5          44.212008  ...            NaN
#
#         Observation Status               Unit of measure Series Type  \
# 0       Excluded from IGME  Deaths per 1,000 live births      Direct
# 1       Excluded from IGME  Deaths per 1,000 live births      Direct
# 2       Excluded from IGME  Deaths per 1,000 live births      Direct
# 3       Excluded from IGME  Deaths per 1,000 live births      Direct
# 4       Excluded from IGME  Deaths per 1,000 live births      Direct
# ...                    ...                           ...         ...
# 129559        Normal value  Deaths per 1,000 live births         NaN
# 129560        Normal value  Deaths per 1,000 live births         NaN
# 129561        Normal value  Deaths per 1,000 live births         NaN
# 129562        Normal value  Deaths per 1,000 live births         NaN
# 129563        Normal value  Deaths per 1,000 live births         NaN
#
#        Series Category                            Series Method  \
# 0               Others  Survey/Census with Full Birth Histories
# 1               Others  Survey/Census with Full Birth Histories
# 2               Others  Survey/Census with Full Birth Histories
# 3               Others  Survey/Census with Full Birth Histories
# 4               Others  Survey/Census with Full Birth Histories
# ...                ...                                      ...
# 129559             NaN                                      NaN
# 129560             NaN                                      NaN
# 129561             NaN                                      NaN
# 129562             NaN                                      NaN
# 129563             NaN                                      NaN
#
#        Age Group of Women Time Since First Birth Definition Interval
# 0                     NaN                    NaN        NaN      5.0
# 1                     NaN                    NaN        NaN      5.0
# 2                     NaN                    NaN        NaN      5.0
# 3                     NaN                    NaN        NaN      5.0
# 4                     NaN                    NaN        NaN      5.0
# ...                   ...                    ...        ...      ...
# 129559                NaN                    NaN        NaN      1.0
# 129560                NaN                    NaN        NaN      1.0
# 129561                NaN                    NaN        NaN      1.0
# 129562                NaN                    NaN        NaN      1.0
# 129563                NaN                    NaN        NaN      1.0
#
# [129564 rows x 23 columns]

# %%
INR.columns
# Out:
# Index(['REF_AREA', 'Geographic area', 'Regional group', 'Indicator', 'Sex',
#        'Wealth Quintile', 'Series Name', 'Series Year', 'Reference Date',
#        'Observation Value', 'Lower Bound', 'Upper Bound', 'Standard Error',
#        'Country notes', 'Observation Status', 'Unit of measure', 'Series Type',
#        'Series Category', 'Series Method', 'Age Group of Women',
#        'Time Since First Birth', 'Definition', 'Interval'],
#       dtype='object')

# %% [markdown]
# ##### 1. Filter data for the eight countries belonging to the East African Community.

# %%
# Filter for EAC countries 
eac_countries = ["Burundi", "Kenya", "Rwanda", "South Sudan", "Tanzania", "Uganda", "Democratic Republic of the Congo", "Somalia"]
eac_inr_data = INR[INR["Geographic area"].isin(eac_countries)]

# %%
eac_inr_data
# Out:
#        REF_AREA Geographic area Regional group                  Indicator  \
# 6387        BDI         Burundi            NaN    Neonatal mortality rate
# 6388        BDI         Burundi            NaN    Neonatal mortality rate
# 6389        BDI         Burundi            NaN    Neonatal mortality rate
# 6390        BDI         Burundi            NaN    Neonatal mortality rate
# 6391        BDI         Burundi            NaN    Neonatal mortality rate
# ...         ...             ...            ...                        ...
# 113635      UGA          Uganda            NaN  Under-five mortality rate
# 113636      UGA          Uganda            NaN  Under-five mortality rate
# 113637      UGA          Uganda            NaN  Under-five mortality rate
# 113638      UGA          Uganda            NaN  Under-five mortality rate
# 113639      UGA          Uganda            NaN  Under-five mortality rate
#
#           Sex Wealth Quintile  \
# 6387    Total           Total
# 6388    Total           Total
# 6389    Total           Total
# 6390    Total           Total
# 6391    Total           Total
# ...       ...             ...
# 113635  Total           Total
# 113636  Total           Total
# 113637  Total           Total
# 113638  Total           Total
# 113639  Total           Total
#
#                                              Series Name Series Year  \
# 6387    Demographic and Health Survey 2016-2017 (Direct)   2016-2017
# 6388    Demographic and Health Survey 2016-2017 (Direct)   2016-2017
# 6389    Demographic and Health Survey 2016-2017 (Direct)   2016-2017
# 6390    Demographic and Health Survey 2016-2017 (Direct)   2016-2017
# 6391    Demographic and Health Survey 2016-2017 (Direct)   2016-2017
# ...                                                  ...         ...
# 113635                                  UN IGME estimate        2023
# 113636                                  UN IGME estimate        2023
# 113637                                  UN IGME estimate        2023
# 113638                                  UN IGME estimate        2023
# 113639                                  UN IGME estimate        2023
#
#         Reference Date  Observation Value  ...  Country notes  \
# 6387            1993.5          36.413480  ...            NaN
# 6388            1998.5          41.259960  ...            NaN
# 6389            2003.5          32.839150  ...            NaN
# 6390            2008.5          28.465570  ...            NaN
# 6391            2013.5          23.706230  ...            NaN
# ...                ...                ...  ...            ...
# 113635          2019.5          45.307572  ...            NaN
# 113636          2020.5          43.509117  ...            NaN
# 113637          2021.5          41.786456  ...            NaN
# 113638          2022.5          40.493282  ...            NaN
# 113639          2023.5          38.807676  ...            NaN
#
#         Observation Status               Unit of measure Series Type  \
# 6387    Excluded from IGME  Deaths per 1,000 live births      Direct
# 6388      Included in IGME  Deaths per 1,000 live births      Direct
# 6389      Included in IGME  Deaths per 1,000 live births      Direct
# 6390      Included in IGME  Deaths per 1,000 live births      Direct
# 6391      Included in IGME  Deaths per 1,000 live births      Direct
# ...                    ...                           ...         ...
# 113635        Normal value  Deaths per 1,000 live births         NaN
# 113636        Normal value  Deaths per 1,000 live births         NaN
# 113637        Normal value  Deaths per 1,000 live births         NaN
# 113638        Normal value  Deaths per 1,000 live births         NaN
# 113639        Normal value  Deaths per 1,000 live births         NaN
#
#        Series Category                            Series Method  \
# 6387               DHS  Survey/Census with Full Birth Histories
# 6388               DHS  Survey/Census with Full Birth Histories
# 6389               DHS  Survey/Census with Full Birth Histories
# 6390               DHS  Survey/Census with Full Birth Histories
# 6391               DHS  Survey/Census with Full Birth Histories
# ...                ...                                      ...
# 113635             NaN                                      NaN
# 113636             NaN                                      NaN
# 113637             NaN                                      NaN
# 113638             NaN                                      NaN
# 113639             NaN                                      NaN
#
#        Age Group of Women Time Since First Birth Definition Interval
# 6387                  NaN                    NaN        NaN      5.0
# 6388                  NaN                    NaN        NaN      5.0
# 6389                  NaN                    NaN        NaN      5.0
# 6390                  NaN                    NaN        NaN      5.0
# 6391                  NaN                    NaN        NaN      5.0
# ...                   ...                    ...        ...      ...
# 113635                NaN                    NaN        NaN      1.0
# 113636                NaN                    NaN        NaN      1.0
# 113637                NaN                    NaN        NaN      1.0
# 113638                NaN                    NaN        NaN      1.0
# 113639                NaN                    NaN        NaN      1.0
#
# [4861 rows x 23 columns]

# %%
eac_inr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4861 entries, 6387 to 113639
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   REF_AREA                4861 non-null   object
#  1   Geographic area         4861 non-null   object
#  2   Regional group          0 non-null      object
#  3   Indicator               4861 non-null   object
#  4   Sex                     4861 non-null   object
#  5   Wealth Quintile         4861 non-null   object
#  6   Series Name             4861 non-null   object
#  7   Series Year             4861 non-null   object
#  8   Reference Date          4861 non-null   float64
#  9   Observation Value       4861 non-null   float64
#  10  Lower Bound             2867 non-null   float64
#  11  Upper Bound             2867 non-null   float64
#  12  Standard Error          1537 non-null   float64
#  13  Country notes           0 non-null      object
#  14  Observation Status      4861 non-null   object
#  15  Unit of measure         4861 non-null   object
#  16  Series Type             1994 non-null   object
#  17  Series Category         1994 non-null   object
#  18  Series Method           1994 non-null   object
#  19  Age Group of Women      384 non-null    object
#  20  Time Since First Birth  50 non-null     object
#  21  Definition              0 non-null      float64
#  22  Interval                4219 non-null   float64
# dtypes: float64(7), object(16)
# memory usage: 911.4+ KB

# %% [markdown]
# I dropped the Regional group, Country notes and Definition columns since it contains null data.

# %%
# Drop Regional group, country notes and definition
columns_to_drop = ['Regional group', 'Country notes','Definition']
eac_inr_data_dropped = eac_inr_data.drop(columns=columns_to_drop, axis=1)
eac_inr_data_dropped
# Out:
#        REF_AREA Geographic area                  Indicator    Sex  \
# 6387        BDI         Burundi    Neonatal mortality rate  Total
# 6388        BDI         Burundi    Neonatal mortality rate  Total
# 6389        BDI         Burundi    Neonatal mortality rate  Total
# 6390        BDI         Burundi    Neonatal mortality rate  Total
# 6391        BDI         Burundi    Neonatal mortality rate  Total
# ...         ...             ...                        ...    ...
# 113635      UGA          Uganda  Under-five mortality rate  Total
# 113636      UGA          Uganda  Under-five mortality rate  Total
# 113637      UGA          Uganda  Under-five mortality rate  Total
# 113638      UGA          Uganda  Under-five mortality rate  Total
# 113639      UGA          Uganda  Under-five mortality rate  Total
#
#        Wealth Quintile                                       Series Name  \
# 6387             Total  Demographic and Health Survey 2016-2017 (Direct)
# 6388             Total  Demographic and Health Survey 2016-2017 (Direct)
# 6389             Total  Demographic and Health Survey 2016-2017 (Direct)
# 6390             Total  Demographic and Health Survey 2016-2017 (Direct)
# 6391             Total  Demographic and Health Survey 2016-2017 (Direct)
# ...                ...                                               ...
# 113635           Total                                  UN IGME estimate
# 113636           Total                                  UN IGME estimate
# 113637           Total                                  UN IGME estimate
# 113638           Total                                  UN IGME estimate
# 113639           Total                                  UN IGME estimate
#
#        Series Year  Reference Date  Observation Value  Lower Bound  \
# 6387     2016-2017          1993.5          36.413480          NaN
# 6388     2016-2017          1998.5          41.259960          NaN
# 6389     2016-2017          2003.5          32.839150          NaN
# 6390     2016-2017          2008.5          28.465570          NaN
# 6391     2016-2017          2013.5          23.706230          NaN
# ...            ...             ...                ...          ...
# 113635        2023          2019.5          45.307572    34.384369
# 113636        2023          2020.5          43.509117    31.686945
# 113637        2023          2021.5          41.786456    29.176171
# 113638        2023          2022.5          40.493282    27.342487
# 113639        2023          2023.5          38.807676    25.246789
#
#         Upper Bound  Standard Error  Observation Status  \
# 6387            NaN        8.279168  Excluded from IGME
# 6388            NaN        5.769786    Included in IGME
# 6389            NaN        3.870619    Included in IGME
# 6390            NaN        4.417056    Included in IGME
# 6391            NaN        2.979608    Included in IGME
# ...             ...             ...                 ...
# 113635    59.772060             NaN        Normal value
# 113636    59.309435             NaN        Normal value
# 113637    59.023163             NaN        Normal value
# 113638    59.214030             NaN        Normal value
# 113639    58.534357             NaN        Normal value
#
#                      Unit of measure Series Type Series Category  \
# 6387    Deaths per 1,000 live births      Direct             DHS
# 6388    Deaths per 1,000 live births      Direct             DHS
# 6389    Deaths per 1,000 live births      Direct             DHS
# 6390    Deaths per 1,000 live births      Direct             DHS
# 6391    Deaths per 1,000 live births      Direct             DHS
# ...                              ...         ...             ...
# 113635  Deaths per 1,000 live births         NaN             NaN
# 113636  Deaths per 1,000 live births         NaN             NaN
# 113637  Deaths per 1,000 live births         NaN             NaN
# 113638  Deaths per 1,000 live births         NaN             NaN
# 113639  Deaths per 1,000 live births         NaN             NaN
#
#                                   Series Method Age Group of Women  \
# 6387    Survey/Census with Full Birth Histories                NaN
# 6388    Survey/Census with Full Birth Histories                NaN
# 6389    Survey/Census with Full Birth Histories                NaN
# 6390    Survey/Census with Full Birth Histories                NaN
# 6391    Survey/Census with Full Birth Histories                NaN
# ...                                         ...                ...
# 113635                                      NaN                NaN
# 113636                                      NaN                NaN
# 113637                                      NaN                NaN
# 113638                                      NaN                NaN
# 113639                                      NaN                NaN
#
#        Time Since First Birth  Interval
# 6387                      NaN       5.0
# 6388                      NaN       5.0
# 6389                      NaN       5.0
# 6390                      NaN       5.0
# 6391                      NaN       5.0
# ...                       ...       ...
# 113635                    NaN       1.0
# 113636                    NaN       1.0
# 113637                    NaN       1.0
# 113638                    NaN       1.0
# 113639                    NaN       1.0
#
# [4861 rows x 20 columns]

# %%
eac_inr_data_dropped['Geographic area'].value_counts()
# Out:
# Geographic area
# Rwanda                              976
# Kenya                               972
# Uganda                              934
# Burundi                             585
# Democratic Republic of the Congo    508
# South Sudan                         506
# Somalia                             380
# Name: count, dtype: int64

# %% [markdown]
# Looks like we have all the EAC countries, except Tanzania.

# %% [markdown]
# ##### 2. Visualize the latest estimate of each indicator at the country level using shapefiles

# %%
# List of ISO codes for the 8 EAC countries
eac_iso_codes = ['BDI', 'KEN', 'RWA', 'SSD', 'UGA', 'COD', 'SOM']

# %%
# Path to the folder with the downloaded shapefiles
folder_path = "eac_shapefiles/"

# %%
#Load and merge all shapefiles
gdfs = []
for iso in eac_iso_codes:
    file_path = os.path.join(folder_path, f"gadm41_{iso}_shp.zip")
    gdf = gpd.read_file(f"zip://{file_path}", layer=f"gadm41_{iso}_0")  # explicitly Level 0
    gdfs.append(gdf)

# %%
# Combine all into one GeoDataFrame
eac_gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))

# %%
eac_gdf.plot();

# %%
eac_gdf
# Out:
#   GID_0                           COUNTRY  \
# 0   BDI                           Burundi
# 1   KEN                             Kenya
# 2   RWA                            Rwanda
# 3   SSD                       South Sudan
# 4   UGA                            Uganda
# 5   COD  Democratic Republic of the Congo
# 6   SOM                           Somalia
#
#                                             geometry
# 0  POLYGON ((30.04515 -4.25684, 30.04523 -4.2576,...
# 1  MULTIPOLYGON (((39.38014 -4.71792, 39.37986 -4...
# 2  POLYGON ((29.71332 -2.81759, 29.71295 -2.81774...
# 3  POLYGON ((29.79568 4.3843, 29.79645 4.38899, 2...
# 4  POLYGON ((29.91125 -1.47687, 29.91099 -1.47613...
# 5  MULTIPOLYGON (((27.24913 -11.79462, 27.2478 -1...
# 6  MULTIPOLYGON (((41.61347 -1.6093, 41.61319 -1....

# %%
# Get latest year
latest_data = eac_inr_data_dropped[eac_inr_data_dropped["Series Year"] == eac_inr_data_dropped["Series Year"].max()]
latest_data
# Out:
#        REF_AREA Geographic area                  Indicator    Sex  \
# 6402        BDI         Burundi    Neonatal mortality rate  Total
# 6403        BDI         Burundi    Neonatal mortality rate  Total
# 6404        BDI         Burundi    Neonatal mortality rate  Total
# 6405        BDI         Burundi    Neonatal mortality rate  Total
# 6406        BDI         Burundi    Neonatal mortality rate  Total
# ...         ...             ...                        ...    ...
# 113635      UGA          Uganda  Under-five mortality rate  Total
# 113636      UGA          Uganda  Under-five mortality rate  Total
# 113637      UGA          Uganda  Under-five mortality rate  Total
# 113638      UGA          Uganda  Under-five mortality rate  Total
# 113639      UGA          Uganda  Under-five mortality rate  Total
#
#        Wealth Quintile       Series Name Series Year  Reference Date  \
# 6402             Total  UN IGME estimate        2023          1964.5
# 6403             Total  UN IGME estimate        2023          1965.5
# 6404             Total  UN IGME estimate        2023          1966.5
# 6405             Total  UN IGME estimate        2023          1967.5
# 6406             Total  UN IGME estimate        2023          1968.5
# ...                ...               ...         ...             ...
# 113635           Total  UN IGME estimate        2023          2019.5
# 113636           Total  UN IGME estimate        2023          2020.5
# 113637           Total  UN IGME estimate        2023          2021.5
# 113638           Total  UN IGME estimate        2023          2022.5
# 113639           Total  UN IGME estimate        2023          2023.5
#
#         Observation Value  Lower Bound  Upper Bound  Standard Error  \
# 6402            49.749877    38.866551    64.063819             NaN
# 6403            49.900299    40.180638    62.476155             NaN
# 6404            49.952441    41.055030    61.440034             NaN
# 6405            49.872070    41.642689    60.657010             NaN
# 6406            49.937962    42.080675    60.111908             NaN
# ...                   ...          ...          ...             ...
# 113635          45.307572    34.384369    59.772060             NaN
# 113636          43.509117    31.686945    59.309435             NaN
# 113637          41.786456    29.176171    59.023163             NaN
# 113638          40.493282    27.342487    59.214030             NaN
# 113639          38.807676    25.246789    58.534357             NaN
#
#        Observation Status               Unit of measure Series Type  \
# 6402         Normal value  Deaths per 1,000 live births         NaN
# 6403         Normal value  Deaths per 1,000 live births         NaN
# 6404         Normal value  Deaths per 1,000 live births         NaN
# 6405         Normal value  Deaths per 1,000 live births         NaN
# 6406         Normal value  Deaths per 1,000 live births         NaN
# ...                   ...                           ...         ...
# 113635       Normal value  Deaths per 1,000 live births         NaN
# 113636       Normal value  Deaths per 1,000 live births         NaN
# 113637       Normal value  Deaths per 1,000 live births         NaN
# 113638       Normal value  Deaths per 1,000 live births         NaN
# 113639       Normal value  Deaths per 1,000 live births         NaN
#
#        Series Category Series Method Age Group of Women  \
# 6402               NaN           NaN                NaN
# 6403               NaN           NaN                NaN
# 6404               NaN           NaN                NaN
# 6405               NaN           NaN                NaN
# 6406               NaN           NaN                NaN
# ...                ...           ...                ...
# 113635             NaN           NaN                NaN
# 113636             NaN           NaN                NaN
# 113637             NaN           NaN                NaN
# 113638             NaN           NaN                NaN
# 113639             NaN           NaN                NaN
#
#        Time Since First Birth  Interval
# 6402                      NaN       1.0
# 6403                      NaN       1.0
# 6404                      NaN       1.0
# 6405                      NaN       1.0
# 6406                      NaN       1.0
# ...                       ...       ...
# 113635                    NaN       1.0
# 113636                    NaN       1.0
# 113637                    NaN       1.0
# 113638                    NaN       1.0
# 113639                    NaN       1.0
#
# [2867 rows x 20 columns]

# %%
# Merge with the shapefile
eac_gdf_with_data = eac_gdf.merge(
    latest_data,
    left_on='GID_0',
    right_on='REF_AREA',
    how='left'
)


eac_gdf_with_data
# Out:
#      GID_0  COUNTRY                                           geometry  \
# 0      BDI  Burundi  POLYGON ((30.04515 -4.25684, 30.04523 -4.2576,...
# 1      BDI  Burundi  POLYGON ((30.04515 -4.25684, 30.04523 -4.2576,...
# 2      BDI  Burundi  POLYGON ((30.04515 -4.25684, 30.04523 -4.2576,...
# 3      BDI  Burundi  POLYGON ((30.04515 -4.25684, 30.04523 -4.2576,...
# 4      BDI  Burundi  POLYGON ((30.04515 -4.25684, 30.04523 -4.2576,...
# ...    ...      ...                                                ...
# 2862   SOM  Somalia  MULTIPOLYGON (((41.61347 -1.6093, 41.61319 -1....
# 2863   SOM  Somalia  MULTIPOLYGON (((41.61347 -1.6093, 41.61319 -1....
# 2864   SOM  Somalia  MULTIPOLYGON (((41.61347 -1.6093, 41.61319 -1....
# 2865   SOM  Somalia  MULTIPOLYGON (((41.61347 -1.6093, 41.61319 -1....
# 2866   SOM  Somalia  MULTIPOLYGON (((41.61347 -1.6093, 41.61319 -1....
#
#      REF_AREA Geographic area                  Indicator    Sex  \
# 0         BDI         Burundi    Neonatal mortality rate  Total
# 1         BDI         Burundi    Neonatal mortality rate  Total
# 2         BDI         Burundi    Neonatal mortality rate  Total
# 3         BDI         Burundi    Neonatal mortality rate  Total
# 4         BDI         Burundi    Neonatal mortality rate  Total
# ...       ...             ...                        ...    ...
# 2862      SOM         Somalia  Under-five mortality rate  Total
# 2863      SOM         Somalia  Under-five mortality rate  Total
# 2864      SOM         Somalia  Under-five mortality rate  Total
# 2865      SOM         Somalia  Under-five mortality rate  Total
# 2866      SOM         Somalia  Under-five mortality rate  Total
#
#      Wealth Quintile       Series Name Series Year  ...  Upper Bound  \
# 0              Total  UN IGME estimate        2023  ...    64.063819
# 1              Total  UN IGME estimate        2023  ...    62.476155
# 2              Total  UN IGME estimate        2023  ...    61.440034
# 3              Total  UN IGME estimate        2023  ...    60.657010
# 4              Total  UN IGME estimate        2023  ...    60.111908
# ...              ...               ...         ...  ...          ...
# 2862           Total  UN IGME estimate        2023  ...   233.961347
# 2863           Total  UN IGME estimate        2023  ...   232.246209
# 2864           Total  UN IGME estimate        2023  ...   230.988120
# 2865           Total  UN IGME estimate        2023  ...   306.188001
# 2866           Total  UN IGME estimate        2023  ...   225.933617
#
#       Standard Error  Observation Status               Unit of measure  \
# 0                NaN        Normal value  Deaths per 1,000 live births
# 1                NaN        Normal value  Deaths per 1,000 live births
# 2                NaN        Normal value  Deaths per 1,000 live births
# 3                NaN        Normal value  Deaths per 1,000 live births
# 4                NaN        Normal value  Deaths per 1,000 live births
# ...              ...                 ...                           ...
# 2862             NaN        Normal value  Deaths per 1,000 live births
# 2863             NaN        Normal value  Deaths per 1,000 live births
# 2864             NaN        Normal value  Deaths per 1,000 live births
# 2865             NaN        Normal value  Deaths per 1,000 live births
# 2866             NaN        Normal value  Deaths per 1,000 live births
#
#       Series Type Series Category Series Method Age Group of Women  \
# 0             NaN             NaN           NaN                NaN
# 1             NaN             NaN           NaN                NaN
# 2             NaN             NaN           NaN                NaN
# 3             NaN             NaN           NaN                NaN
# 4             NaN             NaN           NaN                NaN
# ...           ...             ...           ...                ...
# 2862          NaN             NaN           NaN                NaN
# 2863          NaN             NaN           NaN                NaN
# 2864          NaN             NaN           NaN                NaN
# 2865          NaN             NaN           NaN                NaN
# 2866          NaN             NaN           NaN                NaN
#
#      Time Since First Birth Interval
# 0                       NaN      1.0
# 1                       NaN      1.0
# 2                       NaN      1.0
# 3                       NaN      1.0
# 4                       NaN      1.0
# ...                     ...      ...
# 2862                    NaN      1.0
# 2863                    NaN      1.0
# 2864                    NaN      1.0
# 2865                    NaN      1.0
# 2866                    NaN      1.0
#
# [2867 rows x 23 columns]

# %%
# Filter only Under-5 mortality
u5mr_data = eac_gdf_with_data[eac_gdf_with_data['Indicator'] == 'Under-five mortality rate']

u5mr_data
# Out:
#      GID_0  COUNTRY                                           geometry  \
# 60     BDI  Burundi  POLYGON ((30.04515 -4.25684, 30.04523 -4.2576,...
# 61     BDI  Burundi  POLYGON ((30.04515 -4.25684, 30.04523 -4.2576,...
# 62     BDI  Burundi  POLYGON ((30.04515 -4.25684, 30.04523 -4.2576,...
# 63     BDI  Burundi  POLYGON ((30.04515 -4.25684, 30.04523 -4.2576,...
# 64     BDI  Burundi  POLYGON ((30.04515 -4.25684, 30.04523 -4.2576,...
# ...    ...      ...                                                ...
# 2862   SOM  Somalia  MULTIPOLYGON (((41.61347 -1.6093, 41.61319 -1....
# 2863   SOM  Somalia  MULTIPOLYGON (((41.61347 -1.6093, 41.61319 -1....
# 2864   SOM  Somalia  MULTIPOLYGON (((41.61347 -1.6093, 41.61319 -1....
# 2865   SOM  Somalia  MULTIPOLYGON (((41.61347 -1.6093, 41.61319 -1....
# 2866   SOM  Somalia  MULTIPOLYGON (((41.61347 -1.6093, 41.61319 -1....
#
#      REF_AREA Geographic area                  Indicator     Sex  \
# 60        BDI         Burundi  Under-five mortality rate  Female
# 61        BDI         Burundi  Under-five mortality rate  Female
# 62        BDI         Burundi  Under-five mortality rate  Female
# 63        BDI         Burundi  Under-five mortality rate  Female
# 64        BDI         Burundi  Under-five mortality rate  Female
# ...       ...             ...                        ...     ...
# 2862      SOM         Somalia  Under-five mortality rate   Total
# 2863      SOM         Somalia  Under-five mortality rate   Total
# 2864      SOM         Somalia  Under-five mortality rate   Total
# 2865      SOM         Somalia  Under-five mortality rate   Total
# 2866      SOM         Somalia  Under-five mortality rate   Total
#
#      Wealth Quintile       Series Name Series Year  ...  Upper Bound  \
# 60             Total  UN IGME estimate        2023  ...   282.344236
# 61             Total  UN IGME estimate        2023  ...   279.260820
# 62             Total  UN IGME estimate        2023  ...   278.055835
# 63             Total  UN IGME estimate        2023  ...   277.566531
# 64             Total  UN IGME estimate        2023  ...   277.629557
# ...              ...               ...         ...  ...          ...
# 2862           Total  UN IGME estimate        2023  ...   233.961347
# 2863           Total  UN IGME estimate        2023  ...   232.246209
# 2864           Total  UN IGME estimate        2023  ...   230.988120
# 2865           Total  UN IGME estimate        2023  ...   306.188001
# 2866           Total  UN IGME estimate        2023  ...   225.933617
#
#       Standard Error  Observation Status               Unit of measure  \
# 60               NaN        Normal value  Deaths per 1,000 live births
# 61               NaN        Normal value  Deaths per 1,000 live births
# 62               NaN        Normal value  Deaths per 1,000 live births
# 63               NaN        Normal value  Deaths per 1,000 live births
# 64               NaN        Normal value  Deaths per 1,000 live births
# ...              ...                 ...                           ...
# 2862             NaN        Normal value  Deaths per 1,000 live births
# 2863             NaN        Normal value  Deaths per 1,000 live births
# 2864             NaN        Normal value  Deaths per 1,000 live births
# 2865             NaN        Normal value  Deaths per 1,000 live births
# 2866             NaN        Normal value  Deaths per 1,000 live births
#
#       Series Type Series Category Series Method Age Group of Women  \
# 60            NaN             NaN           NaN                NaN
# 61            NaN             NaN           NaN                NaN
# 62            NaN             NaN           NaN                NaN
# 63            NaN             NaN           NaN                NaN
# 64            NaN             NaN           NaN                NaN
# ...           ...             ...           ...                ...
# 2862          NaN             NaN           NaN                NaN
# 2863          NaN             NaN           NaN                NaN
# 2864          NaN             NaN           NaN                NaN
# 2865          NaN             NaN           NaN                NaN
# 2866          NaN             NaN           NaN                NaN
#
#      Time Since First Birth Interval
# 60                      NaN      1.0
# 61                      NaN      1.0
# 62                      NaN      1.0
# 63                      NaN      1.0
# 64                      NaN      1.0
# ...                     ...      ...
# 2862                    NaN      1.0
# 2863                    NaN      1.0
# 2864                    NaN      1.0
# 2865                    NaN      1.0
# 2866                    NaN      1.0
#
# [2498 rows x 23 columns]

# %%
# Group by country (Location) and take mean Observation value
u5mr_data_grouped = u5mr_data.groupby('Geographic area', as_index=False)['Observation Value'].mean()

# Merge back with geometry (from original shapefile)
u5mr_map = eac_gdf_with_data[['Geographic area', 'geometry']].drop_duplicates().merge(u5mr_data_grouped, on='Geographic area', how='inner')

# %%
# Plot Under five mortality rate map
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
u5mr_map.plot(column='Observation Value', cmap='OrRd', legend=True, ax=ax, edgecolor='black')
ax.set_title('Under-5 Mortality Rate (U5MR) - Latest Estimate (Average)')
ax.axis('off')
plt.show()


# --- Prepare Neonatal Mortality Rate (NMR) data ---

nmr_data = eac_gdf_with_data[eac_gdf_with_data['Indicator'] == 'Neonatal mortality rate']

# Group by country (Location) and take mean Observation value
nmr_data_grouped = nmr_data.groupby('Geographic area', as_index=False)['Observation Value'].mean()

# Merge back with geometry
nmr_map = eac_gdf_with_data[['Geographic area', 'geometry']].drop_duplicates().merge(nmr_data_grouped, on='Geographic area', how='inner')

# Plot neonatal mortality rate map
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
nmr_map.plot(column='Observation Value', cmap='PuBu', legend=True, ax=ax, edgecolor='black')
ax.set_title('Neonatal Mortality Rate (NMR) - Latest Estimate (Average)')
ax.axis('off')
plt.show()

# %% [markdown]
# ###### Show the average trends in the mortality rates over time (plot the average trend line and add the points in the graphic for the country level estimates for each indicator.

# %%
# --- Step 1: Average multiple observations per country, year, and indicator ---
eac_avg = eac_inr_data_dropped.groupby(['Geographic area', 'Series Year', 'Indicator'], as_index=False)['Observation Value'].mean()

# --- Step 2: Pivot data to get U5MR and NMR in separate columns ---
eac_pivot = eac_avg.pivot(index=['Geographic area', 'Series Year'], columns='Indicator', values='Observation Value').reset_index()

# Rename columns for clarity
eac_pivot = eac_pivot.rename(columns={
    'Under-five mortality rate': 'U5MR_value',
    'Neonatal mortality rate': 'NMR_value'
})

# %%
# --- Plot U5MR ---
plt.figure(figsize=(10,6))

# Plot individual country points
sns.scatterplot(data=eac_pivot, x='Series Year', y='U5MR_value', hue='Geographic area', alpha=0.4, legend=False)

# Plot the average trend
sns.lineplot(data=eac_pivot.groupby('Series Year')['U5MR_value'].mean().reset_index(),
             x='Series Year', y='U5MR_value', color='black', linewidth=2, label='Average U5MR')

# Finalize plot
plt.title('Average Trend of Under-5 Mortality Rate (U5MR) Over Time (East Africa)')
plt.ylabel('U5MR (per 1,000 live births)')
plt.xlabel('Year')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

eac_pivot.replace([np.inf, -np.inf], np.nan, inplace=True)  

# --- Plot NMR ---
plt.figure(figsize=(10,6))

# Plot individual country points
sns.scatterplot(data=eac_pivot, x='Series Year', y='NMR_value', hue='Geographic area', alpha=0.4, legend=False)

# Plot the average trend
sns.lineplot(data=eac_pivot.groupby('Series Year')['NMR_value'].mean().reset_index(),
             x='Series Year', y='NMR_value', color='black', linewidth=2, label='Average NMR')

# Finalize plot
plt.title('Average Trend of Neonatal Mortality Rate (NMR) Over Time (East Africa)')
plt.ylabel('NMR (per 1,000 live births)')
plt.xlabel('Year')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
